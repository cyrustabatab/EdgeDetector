# %%
from google.colab import drive
import pandas as pd
import numpy as np
import cv2 
import matplotlib.pyplot as plt
from imutils import paths

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
images = list(paths.list_images("gdrive/My Drive/datasets/Edge Detector/"))
pictures = []

for image in images:
  pictures.append(cv2.imread(image,0))

# %%
figure = plt.figure(figsize=(20,12))
for i,picture in enumerate(pictures):
  subplot = figure.add_subplot(3,3,i+1)
  subplot.imshow(picture,cmap='gray')

# %%
def avgPixel(picture):
  average = 0
  row,col = picture.shape
  for y in picture:
    for x in y:
        average += x
  return int(average/(row*col)-30),int(average/(row*col)+30)

# %%
figure = plt.figure(figsize=(20,20))
double = cv2.resize(pictures[6],fx=2,fy=2,dsize=None)
low,high = avgPixel(pictures[6])
double = cv2.Canny(double,low,high)
plt.imshow(double,cmap="gray")

# %%
avgPixel(pictures[2])
# Out:
# (110, 170)
